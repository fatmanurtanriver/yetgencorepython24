# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
def urun_ekleme ():
    while True:
        urun=input("ürün adını giriniz(çıkmak için q'ya basınız):")
        if urun=="q":
            break
        fiyat=float(input("ürün fiyatını giriniz:"))
        print("ürün başarıyla kaydedildi.")
        with open("urunler.txt", "a", encoding="utf-8") as file:
            file.write(f"{urun}:{fiyat}\n")

urun_ekleme()
# Out:
# ürün başarıyla kaydedildi.
# ürün başarıyla kaydedildi.
# ürün başarıyla kaydedildi.

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

def urun_bilgisi_degistirme():
    eski_kelime=input("değiştirmek istediğiniz ürün bilgisinin adını giriniz:")
    yeni_kelime=input("yeni ürünün adını giriniz:")
    with open("urunler.txt", "r+", encoding="utf-8") as file:
        kelime=file.read()
        file.seek(0)
        yeni_metin=kelime.replace(eski_kelime,yeni_kelime)
        file.write(yeni_metin)
    print("ürün bilgisi başarıyla kaydedildi !")

urun_bilgisi_degistirme()
# Out:
# ürün bilgisi başarıyla kaydedildi !

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız

class vehicle():
    def __init__ (self,name, speed, mileage):
        self.name=name
        self.speed=speed
        self.mileage=mileage

    def obje_output(self):
        print(f"Name:{self.name} Speed: {self.speed} Mileage: {self.mileage}")

class Bus(vehicle):
    def __init__(self, name, speed, mileage):
        super().__init__(name,speed,mileage)

bus=Bus("School Volvo", 180, 12)
bus.obje_output()
# Out:
# Name:School Volvo Speed: 180 Mileage: 12
